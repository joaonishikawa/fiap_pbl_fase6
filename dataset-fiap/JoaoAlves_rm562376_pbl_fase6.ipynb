# %% [markdown]
# # PBL Fase 6 - Visão Computacional (FarmTech Solutions)
# **Objetivo:** Desenvolver e comparar modelos de Visão Computacional para detecção e classificação de objetos, demonstrando aplicabilidade prática para a FarmTech Solutions.
#
# ## Entrega 1: Detecção de Objetos com YOLOv5 Customizado
# Nesta primeira etapa, organizamos um dataset próprio contendo 80 imagens divididas entre duas classes (`caneca` e `relogio`). As imagens foram rotuladas manualmente utilizando o Make Sense AI.
#
# Abaixo, iniciamos a preparação do ambiente, conectando o Google Drive para acessar o dataset e clonando o repositório oficial do YOLOv5.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -qr requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17898, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 17898 (delta 38), reused 12 (delta 11), pack-reused 17840 (from 5)
# Receiving objects: 100% (17898/17898), 17.05 MiB | 26.74 MiB/s, done.
# Resolving deltas: 100% (12185/12185), done.
# /content/yolov5
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 39.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 14.8 MB/s eta 0:00:00

# %% [markdown]
# ### Simulação 1: Treinamento do YOLO Adaptado (30 Épocas)
# Para a nossa primeira simulação, configuramos o algoritmo para treinar por 30 épocas.
# Utilizamos os pesos pré-treinados do modelo leve do YOLO (`yolov5s.pt`) para acelerar o aprendizado (Transfer Learning) e definimos o tamanho das imagens para 640x640 pixels. O arquivo `data.yaml` foi configurado para mapear os caminhos das pastas de treino e validação no Drive.

# %%
# !python train.py --img 640 --batch 16 --epochs 30 --data /content/drive/MyDrive/dataset-fiap/data.yaml --weights yolov5s.pt
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: WARNING W&B disabled due to login timeout.
# wandb: ERROR Error while calling W&B API: api key too short (<Response [401]>)
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# ...

# %% [markdown]
# ### Inferência (Teste) - Modelo de 30 Épocas
# Com o primeiro "cérebro" treinado, vamos aplicar os melhores pesos gerados (`best.pt`) nas imagens inéditas da nossa pasta de Teste. O nível de confiança mínimo foi ajustado para 25% (`--conf 0.25`). O objetivo é verificar se o modelo já consegue localizar e classificar os objetos com essa quantidade inicial de treino.

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/dataset-fiap/images/test
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/dataset-fiap/images/test, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-478-g6c66ecd5 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/8 /content/drive/MyDrive/dataset-fiap/images/test/IMG_6812.jpg: 640x480 1 caneca, 37.8ms
# image 2/8 /content/drive/MyDrive/dataset-fiap/images/test/IMG_6823.jpg: 640x480 1 caneca, 10.6ms
# ...

# %% [markdown]
# ### Simulação 2: Treinamento do YOLO Adaptado (60 Épocas)
# Atendendo aos requisitos do projeto, realizamos uma segunda simulação dobrando a quantidade de iterações (60 épocas). O intuito desta simulação é observar o comportamento das métricas de erro (Loss) e acurácia (mAP) e avaliar se um tempo maior de exposição aos dados refina a detecção ou se acaba induzindo o modelo ao *overfitting* (sobreajuste), dado o tamanho reduzido do nosso dataset.

# %%
# !python train.py --img 640 --batch 16 --epochs 60 --data /content/drive/MyDrive/dataset-fiap/data.yaml --weights yolov5s.pt
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# wandb: WARNING W&B disabled due to login timeout.
# wandb: ERROR Error while calling W&B API: api key too short (<Response [401]>)
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# ...

# %% [markdown]
# ### Inferência (Teste) - Modelo de 60 Épocas
# Aplicando agora os pesos resultantes do treinamento mais longo nas mesmas imagens de teste para compararmos visualmente os resultados práticos das *bounding boxes* e os níveis de confiança.

# %%
# !python detect.py --weights runs/train/exp2/weights/best.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/dataset-fiap/images/test

# %% [markdown]
# ---
# ## Entrega 2: Comparação de Abordagens
#
# ### Teste com YOLO Tradicional (Sem Customização)
# Como primeira base de comparação, vamos testar o YOLOv5 padrão com seus pesos originais (treinados no gigantesco dataset COCO) aplicados diretamente nas nossas imagens de teste. O objetivo é analisar como um modelo generalista de alta capacidade reage aos nossos objetos em comparação ao nosso modelo customizado restrito.

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/dataset-fiap/images/test --name teste_yolo_padrao
